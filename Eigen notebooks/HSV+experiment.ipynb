# %%
# %%time
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

#print("Python version: \n" + sys.version)
#print("cv2 version: " + cv2.__version__)

img1 = cv2.imread('IMG_8423.JPG')
img2 = 'test_image_zero.png'
hsv1 = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(hsv1)

# img2 = cv2.cvtColor(h, cv2.COLOR_HSV2BGR)

#img3 = cv2.imwrite('coke.png', h)

#img2 = cv2.cvtColor(img4, cv2.COLOR_HSV2BGR)
plt.imshow(img1)
plt.show()
plt.imshow(hsv1)
plt.show()
plt.imshow(h)
plt.show()
plt.imshow(s)
plt.show()
plt.imshow(v)
plt.show()
#print(cv2.imread('test_image_kitti.png'))
#print(img3)
# Out:
# CPU times: user 3.88 s, sys: 2.03 s, total: 5.91 s
# Wall time: 2.74 s

# %%
# %%time
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt


#print("Python version: \n" + sys.version)
#print("cv2 version: " + cv2.__version__)
img1 = cv2.imread('IMG_8423.JPG')
hsv1 = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)
#h,s,v = cv2.split(hsv1)
plt.imsave('testhue6.png', hsv1)
# Out:
# CPU times: user 7.28 s, sys: 242 ms, total: 7.52 s
# Wall time: 6.23 s

# %%
# %%time
#img1 = cv2.imread('test_image_kitti.png')
hsv1 = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)

h,s,v = cv2.split(hsv1)
#plt.imsave('testhue.png', h)
# Out:
# CPU times: user 490 ms, sys: 0 ns, total: 490 ms
# Wall time: 19.6 ms
